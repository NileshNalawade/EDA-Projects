# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("shopping_trends.csv")

# %%
data.shape
# Out:
# (3900, 19)

# %%
data.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
data.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
data.shape
# Out:
# (3900, 19)

# %%
data.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
data.duplicated().sum()
#to find number of duplicate entrys
# Out:
# 0

# %%
data["Age"].plot(kind ="hist")
plt.title("histogram of age")
plt.show()
# histogram to show age group of customers shopping

# %%
data.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %%
data["Gender"].value_counts().plot(kind="bar")
plt.title("Gender Distribution")
plt.show()
# gender wise distribution of customers

# %%
data.groupby("Category")["Purchase Amount (USD)"].sum().plot(kind="pie",label="",explode =(0,0.1,0,0),autopct ='%1.1f%%',shadow = True)
# Total money spent on each item

# %%
data.sort_values("Review Rating", ascending= False)
#sorting the data rating wise
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 776           777   49    Male          Shirt     Clothing
# 1664         1665   19    Male        Handbag  Accessories
# 1277         1278   19    Male         Blouse     Clothing
# 2632         2633   24    Male          Scarf  Accessories
# 965           966   43    Male          Boots     Footwear
# ...           ...  ...     ...            ...          ...
# 1451         1452   54    Male         Jacket    Outerwear
# 3473         3474   63  Female          Dress     Clothing
# 1449         1450   18    Male          Socks     Clothing
# 133           134   52    Male        Sweater     Clothing
# 870           871   66    Male         Hoodie     Clothing
#
#       Purchase Amount (USD)       Location Size     Color  Season  \
# 776                      60        Alabama    M    Maroon  Spring
# 1664                     53      Minnesota    M    Purple  Spring
# ...

# %%
data["Subscription Status"].value_counts().plot(kind="pie",explode =(0,0.1),autopct ='%1.1f%%',shadow = True)
plt.title("Subscription Status")
plt.show()
# check subscripton status

# %%
plt.figure(figsize=(7,7))
data["Color"].value_counts().plot(kind="pie",autopct ='%1.1f%%')

# %%
data.groupby("Season")["Purchase Amount (USD)"].sum().plot(kind="pie",autopct ='%1.1f%%',shadow = True)
# pie chart to check the difference bitween shopping paterns by season

# %%
data.boxplot(column = "Purchase Amount (USD)", by = "Category", figsize=(7,7))
plt.title("frequency of perchase to spending")
plt.show()
# comparing money spent on each category

# %%
data["Preferred Payment Method"].value_counts().plot(kind="pie",autopct ='%1.1f%%',shadow = True
                                                     ,explode =(0,0,0.1,0,0,0),label="")
# prefered payment method

# %%
data.groupby("Payment Method")["Purchase Amount (USD)"].sum().plot(kind = "pie",label="",explode =(0,0,0.1,0,0,0),autopct ='%1.1f%%')
plt.show()
# Total Payments made py each method

# %%
data.groupby("Payment Method")["Purchase Amount (USD)"].sum()
# Out:
# Payment Method
# Bank Transfer    37123
# Cash             38833
# Credit Card      42567
# Debit Card       37118
# PayPal           37449
# Venmo            39991
# Name: Purchase Amount (USD), dtype: int64

# %%
pd.pivot_table(data,values = "Purchase Amount (USD)",index= "Location", columns="Item Purchased", aggfunc="mean").head()
# Out:
# Item Purchased  Backpack       Belt  Blouse      Boots       Coat      Dress  \
# Location
# Alabama             74.0  26.500000    52.0  73.666667  54.500000  55.200000
# Alaska              74.6  76.750000    67.5  56.000000  45.500000  74.500000
# Arizona             48.6  84.500000    61.0        NaN  65.333333  71.000000
# Arkansas            90.0  55.000000    66.0  50.000000  54.250000  62.800000
# California          57.4  61.666667    39.5  62.500000  55.000000  58.428571
#
# Item Purchased     Gloves    Handbag        Hat     Hoodie  ...      Scarf  \
# Location                                                    ...
# Alabama         85.000000  57.666667  76.000000  53.000000  ...  75.333333
# Alaska          66.333333  46.000000  52.666667  56.500000  ...  45.000000
# Arizona         87.000000  58.666667  87.000000  66.666667  ...  53.500000
# Arkansas        64.333333  50.000000  35.000000  55.250000  ...  67.500000
# ...

# %%
data.groupby("Size")["Purchase Amount (USD)"].sum().plot(kind="bar")
#

# %%
data.groupby('Size')['Purchase Amount (USD)'].sum().plot(kind="pie",autopct ='%1.1f%%')

# %%
data.groupby("Discount Applied")["Review Rating"].mean()
#check if discouts affected the ratings of products
# Out:
# Discount Applied
# No     3.757715
# Yes    3.739654
# Name: Review Rating, dtype: float64

# %%
data.groupby("Category")["Color"].value_counts()
#avaibality of colors for each category
# Out:
# Category     Color
# Accessories  Olive       66
#              Blue        59
#              Gray        59
#              Magenta     58
#              Peach       58
#                          ..
# Outerwear    Charcoal    10
#              Red         10
#              Maroon       8
#              Orange       8
#              Peach        8
# Name: Color, Length: 100, dtype: int64

# %%
data.groupby("Frequency of Purchases")["Previous Purchases"].median()
# Out:
# Frequency of Purchases
# Annually          24
# Bi-Weekly         24
# Every 3 Months    24
# Fortnightly       26
# Monthly           25
# Quarterly         28
# Weekly            26
# Name: Previous Purchases, dtype: int64

# %%
plt.figure(figsize=(7,7))
data.groupby("Item Purchased")["Purchase Amount (USD)"].mean().plot(kind="bar")
# average cost of each item sold

# %%
plt.figure(figsize=(10,10))
data.groupby("Color")["Review Rating"].mean().plot(kind="bar")
plt.xlabel("Color")
plt.ylabel("Mean Review Rating")
plt.show()

# %%
data["Season"].value_counts().plot(kind="bar")
plt.xlabel("Season")
plt.ylabel("Count")
plt.title("count of purchases each season")
plt.show()

# %%
data["Category"].value_counts().plot(kind="pie",explode =(0.1,0,0,0),autopct ='%1.1f%%')
plt.title("Distribution of purchases by category")
plt.show()
#

# %%
sns.boxplot(x="Gender",y="Review Rating",data=data)
plt.xlabel("Gender")
plt.ylabel("Review Rating")
plt.title("Review per gender")
plt.show()
#comparing gender based review rating

# %%
data["Purchase Amount (USD)"].plot(kind = "hist", bins = 10)
plt.xlabel("USD")
plt.ylabel("Frequency")
plt.title=("Purchase amount distribution")
plt.show()
# frequency of mony spent

# %%
data.boxplot(column ="Purchase Amount (USD)", by = "Frequency of Purchases")
plt.xlabel("frequencyy of purchases")
plt.ylabel("")
plt.show()
#shopping patters of shppers on timly basis

# %% [markdown]
# findings
# 1. data had no null values
#
# 2. Data had 0 duplicate entrys
#
# 3. number of female shoppers surpassed that of male shoppers
#
# 4. clothing sector had moximum amout of sales
#
# 5. 27.0% shoppers do not have subscription
#
# 6. there were no affect of season on spending of shppers
#
# 7. money spent on clothind and footwear is slighly higher than that of other categorys
#
# 8. most shoppers prefer cash mode of payment
#
# 9. although most shppers prefer cash mode shoppers who prefer Credit Card payments spend more
#
# 10. sales are maximum for medium category of categorys
#
# 11. No affect of discounts on product review ratings
#
# 12. male shoppers are likely to give higher ratings to product than female shoppers
